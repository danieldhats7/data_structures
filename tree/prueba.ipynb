# %%
from BST import *

# %%
n1 = Node(4)
n2 = Node(6)
n3 = Node(2)
n4 = Node(5)

# %%
tree = BST(n1)

# %%
tree.insert(n2)
tree.insert(n3)
tree.insert(n4)

# %%
print(tree)
# Out:
# 2 4 5 6

# %%
tree.maxdepth()
# Out:
# 3
